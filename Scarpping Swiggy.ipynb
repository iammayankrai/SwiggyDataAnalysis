# %%
import requests
import html_to_json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from pyshadow.main import Shadow
from bs4 import BeautifulSoup
import time

# %%
# !pip install html-to-json
# Out:
# Requirement already satisfied: html-to-json in c:\users\mayan\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: bs4 in c:\users\mayan\anaconda3\lib\site-packages (from html-to-json) (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\mayan\anaconda3\lib\site-packages (from bs4->html-to-json) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mayan\anaconda3\lib\site-packages (from beautifulsoup4->bs4->html-to-json) (2.3.1)

# %%
# !pip install pyshadow
# Out:
# Requirement already satisfied: pyshadow in c:\users\mayan\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: multipledispatch>=0.6.0 in c:\users\mayan\anaconda3\lib\site-packages (from pyshadow) (0.6.0)
# Requirement already satisfied: selenium>=3.141.0 in c:\users\mayan\anaconda3\lib\site-packages (from pyshadow) (4.8.3)
# Requirement already satisfied: webdriver-manager>=2.5.3 in c:\users\mayan\anaconda3\lib\site-packages (from pyshadow) (3.8.5)
# Requirement already satisfied: six in c:\users\mayan\anaconda3\lib\site-packages (from multipledispatch>=0.6.0->pyshadow) (1.16.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\mayan\anaconda3\lib\site-packages (from selenium>=3.141.0->pyshadow) (2022.9.14)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\mayan\anaconda3\lib\site-packages (from selenium>=3.141.0->pyshadow) (1.26.11)
# Requirement already satisfied: trio~=0.17 in c:\users\mayan\anaconda3\lib\site-packages (from selenium>=3.141.0->pyshadow) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\mayan\anaconda3\lib\site-packages (from selenium>=3.141.0->pyshadow) (0.10.2)
# Requirement already satisfied: requests in c:\users\mayan\anaconda3\lib\site-packages (from webdriver-manager>=2.5.3->pyshadow) (2.28.1)
# Requirement already satisfied: tqdm in c:\users\mayan\anaconda3\lib\site-packages (from webdriver-manager>=2.5.3->pyshadow) (4.64.1)
# Requirement already satisfied: packaging in c:\users\mayan\anaconda3\lib\site-packages (from webdriver-manager>=2.5.3->pyshadow) (21.3)
# Requirement already satisfied: python-dotenv in c:\users\mayan\anaconda3\lib\site-packages (from webdriver-manager>=2.5.3->pyshadow) (1.0.0)
# Requirement already satisfied: idna in c:\users\mayan\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.141.0->pyshadow) (3.3)
# Requirement already satisfied: sniffio in c:\users\mayan\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.141.0->pyshadow) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\mayan\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.141.0->pyshadow) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\mayan\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.141.0->pyshadow) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\mayan\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.141.0->pyshadow) (21.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\mayan\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.141.0->pyshadow) (1.15.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\mayan\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.141.0->pyshadow) (1.1.1)
# Requirement already satisfied: outcome in c:\users\mayan\anaconda3\lib\site-packages (from trio~=0.17->selenium>=3.141.0->pyshadow) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\mayan\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium>=3.141.0->pyshadow) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\mayan\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium>=3.141.0->pyshadow) (1.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mayan\anaconda3\lib\site-packages (from packaging->webdriver-manager>=2.5.3->pyshadow) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mayan\anaconda3\lib\site-packages (from requests->webdriver-manager>=2.5.3->pyshadow) (2.0.4)
# Requirement already satisfied: colorama in c:\users\mayan\anaconda3\lib\site-packages (from tqdm->webdriver-manager>=2.5.3->pyshadow) (0.4.5)
# Requirement already satisfied: pycparser in c:\users\mayan\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium>=3.141.0->pyshadow) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\mayan\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium>=3.141.0->pyshadow) (0.14.0)

# %%
base_url = "https://www.swiggy.com/"
driver = webdriver.Chrome()

driver.get(base_url)
location_element = driver.find_element(by=By.XPATH, value='//*[@id="location"]')
# location = input("enter a city: ")
location = "Bangalore"
location_element.send_keys(location)
location_element.send_keys(Keys.ENTER)
time.sleep(3)
# html = location_element.get_attribute("innerHTML")
# soup = BeautifulSoup(html)
# print(soup.prettify())
driver.find_element(by=By.XPATH,
                    value='//*[@id="root"]/div[1]/div[1]/div/div[1]/div[1]/div/div[2]/div/div[2]/button[1]').click()
time.sleep(5)
# ele = driver.find_elements(by = By.XPATH, value='//*[@id="all_restaurants"]/div/div[2]/div[1]/div/div')
# print(len(ele))

# height = driver.get_window_size()
# height1 = height['height']

max_element_val = driver.find_element(by=By.XPATH,
                                      value='//*[@id="all_restaurants"]/div/div[1]/div/div/div/div[1]').text
max_element_val = int(max_element_val.split()[0])
#print(max_element_val)

j = 0
k = 1000
while True:
    driver.execute_script(f"window.scrollTo({j}, {k});")
    time.sleep(1)
    ele = driver.find_elements(by=By.XPATH, value='//*[@id="all_restaurants"]/div/div[2]/div[1]/div/div')
    print(len(ele))
    if len(ele) >= (max_element_val // 4):
        break
    else:
        j = j + 500
        k = k + 500

#     if element_val<len(ele):
#         element_val = len(ele)
#         height1 = height1*4
    
#     else:
#         break

print("we are here outside the while loop")

elements = driver.find_elements(by=By.XPATH, value='//*[@id="all_restaurants"]/div/div[2]/div[1]/div/div')
print(len(elements))
# Out:
# 4
# 8
# 8
# 8
# 8
# 12
# 12
# 12
# 12
# 16
# 16
# 16
# 20
# 20
# 24
# 24
# 24
# 24
# 28
# 28
# 28
# 28
# 32
# 32
# 32
# 32
# 32
# 36
# 36
# 40
# 40
# 44
# 44
# 44
# 48
# 48
# 48
# 52
# 52
# 52
# 52
# 56
# 56
# 56
# 60
# 60
# 60
# 64
# 64
# 64
# 64
# 68
# 68
# 68
# 72
# 72
# 72
# 72
# 76
# 76
# 80
# 80
# 80
# 80
# 84
# 84
# 84
# 88
# 88
# 88
# 92
# 92
# 92
# 96
# 96
# 96
# 96
# 100
# 100
# 100
# 104
# 104
# 104
# 108
# 108
# 108
# 112
# 112
# 112
# 112
# 116
# 116
# 116
# 120
# 120
# 120
# 124
# 124
# 124
# 128
# 128
# 128
# 128
# 132
# 132
# 132
# 136
# 136
# 136
# 140
# 140
# 140
# 140
# 144
# we are here outside the while loop
# 144

# %%
ele = elements[0]

# %%
html1 = ele.get_attribute("innerHTML")
html1
# Out:
# '<div class="_3XX_A"><a href="/restaurants/burger-seigneur-indiranagar-bangalore-341895" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_2tuBw _12_oN" alt="Burger Seigneur" width="254" height="160" src="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/k4z46joj5ozirqpyww1z"></div><div class="IJsqo" style="background: rgb(58, 60, 65); color: rgb(255, 255, 255); border-color: rgb(30, 32, 35) transparent;"><div class="_1kXWW">Promoted</div></div><div class="_3Ztcd"><div class="nA6kb">Burger Seigneur</div><div class="_1gURR" title="American, Continental, Burgers, Beverages">American, Continental, Burgers, Beverages</div></div><div class="_3Mn31"><div class="_9uwBC wY0my"><span class="icon-star _537e4"></span><span>4.3</span></div><div>•</div><div>28 MINS</div><div>•</div><div class="nVWSi">₹1300 FOR TWO</div></div></div><div class="_3B2qG"><span role="button" aria-label="Open" class="_2ECk4 _24tlh">Quick View</span></div></div></a></div><div class="_3XX_A"><a href="/restaurants/raidan-authentic-arabian-restaurant-kacharakanahalli-kammanahalli-kalyan-nagar-bangalore-69720" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_2tuBw _12_oN" alt="Raidan- Authentic Arabian Restaurant" width="254" height="160" src="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/euo9db9sbvsrgi4v7lhq"></div><div class="_3Ztcd"><div class="nA6kb">Raidan- Authentic Arabian Restaurant</div><div class="_1gURR" title="Arabian, Chinese, Beverages, Mughlai">Arabian, Chinese, Beverages, Mughlai</div></div><div class="_3Mn31"><div class="_9uwBC _2lAlc"><span class="icon-star _537e4"></span><span>3.9</span></div><div>•</div><div>30 MINS</div><div>•</div><div class="nVWSi">₹400 FOR TWO</div></div><div class="Zlfdx"><span class="icon-offer-filled _2fujs"></span><span class="sNAfh">FLAT100 off | Use FLATDEAL</span></div></div><div class="_3B2qG"><span role="button" aria-label="Open" class="_2ECk4 _24tlh">Quick View</span></div></div></a></div><div class="_3XX_A"><a href="/restaurants/the-dessert-zone-2nd-stage-indiranagar-bangalore-238565" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_2tuBw _12_oN" alt="The Dessert Zone" width="254" height="160" src="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/c447c9ce7d0bbe78e46141e866236762"></div><div class="_3Ztcd"><div class="nA6kb">The Dessert Zone</div><div class="_1gURR" title="Bakery, Desserts, Ice Cream, Beverages">Bakery, Desserts, Ice Cream, Beverages</div></div><div class="_3Mn31"><div class="_9uwBC wY0my"><span class="icon-star _537e4"></span><span>4.2</span></div><div>•</div><div>23 MINS</div><div>•</div><div class="nVWSi">₹200 FOR TWO</div></div><div class="Zlfdx"><span class="icon-offer-filled _2fujs"></span><span class="sNAfh">FLAT125 off | Use FLATDEAL</span></div></div><div class="_3B2qG"><span role="button" aria-label="Open" class="_2ECk4 _24tlh">Quick View</span></div></div></a></div><div class="_3XX_A"><a href="/restaurants/noto-healthy-ice-cream-guddadahalli-hebbal-rt-nagar-bangalore-567207" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_2tuBw _12_oN" alt="NOTO - Healthy Ice Cream" width="254" height="160" src="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/51bd9c7efcc0e05c614c0e0674434e62"></div><div class="IJsqo" style="background: rgb(58, 60, 65); color: rgb(255, 255, 255); border-color: rgb(30, 32, 35) transparent;"><div class="_1kXWW">Promoted</div></div><div class="_3Ztcd"><div class="nA6kb">NOTO - Healthy Ice Cream</div><div class="_1gURR" title="Ice Cream, Desserts">Ice Cream, Desserts</div></div><div class="_3Mn31"><div class="_9uwBC wY0my"><span class="icon-star _537e4"></span><span>4.3</span></div><div>•</div><div>28 MINS</div><div>•</div><div class="nVWSi">₹250 FOR TWO</div></div><di ...

# %%
ele1 = elements[1]
html2 = ele1.get_attribute("innerHTML")
html2
# Out:
# '<div class="_3XX_A"><a href="/restaurants/kouzina-kafe-the-food-court-cmh-road-indiranagar-bangalore-391280" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_12_oN" alt="Kouzina Kafe - The Food Court" width="254" height="160"></div><div class="_3Ztcd"><div class="nA6kb">Kouzina Kafe - The Food Court</div><div class="_1gURR" title="Bakery, Desserts, Ice Cream, Beverages">Bakery, Desserts, Ice Cream, Beverages</div></div><div class="_3Mn31"><div class="_9uwBC wY0my"><span class="icon-star _537e4"></span><span>4.2</span></div><div>•</div><div>33 MINS</div><div>•</div><div class="nVWSi">₹150 FOR TWO</div></div><div class="Zlfdx"><span class="icon-offer-filled _2fujs"></span><span class="sNAfh">40% off | Use TRYNEW</span></div></div><div class="_3B2qG"><span role="button" aria-label="Open" class="_2ECk4 _24tlh">Quick View</span></div></div></a></div><div class="_3XX_A"><a href="/restaurants/pipabu-4th-block-koramangala-bangalore-45757" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_12_oN" alt="Pipabu" width="254" height="160"></div><div class="_3Ztcd"><div class="nA6kb">Pipabu</div><div class="_1gURR" title="Pizzas, Italian, American, Continental, Salads, Desserts">Pizzas, Italian, American, Continental, Salads, Desserts</div></div><div class="_3Mn31"><div class="_9uwBC wY0my"><span class="icon-star _537e4"></span><span>4.1</span></div><div>•</div><div>30 MINS</div><div>•</div><div class="nVWSi">₹250 FOR TWO</div></div><div class="Zlfdx"><span class="icon-offer-filled _2fujs"></span><span class="sNAfh">20% off | Use TRYNEW</span></div></div><div class="_3B2qG"><span role="button" aria-label="Open" class="_2ECk4 _24tlh">Quick View</span></div></div></a></div><div class="_3XX_A"><a href="/restaurants/chopstick-armane-nagar-r-t-nagar-bangalore-312849" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_12_oN" alt="Chopstick" width="254" height="160"></div><div class="IJsqo" style="background: rgb(58, 60, 65); color: rgb(255, 255, 255); border-color: rgb(30, 32, 35) transparent;"><div class="_1kXWW">Promoted</div></div><div class="_3Ztcd"><div class="nA6kb">Chopstick</div><div class="_1gURR" title="Chinese, Thai, Seafood, Asian, Combo, Healthy Food, Beverages">Chinese, Thai, Seafood, Asian, Combo, Healthy Food, Beverages</div></div><div class="_3Mn31"><div class="_9uwBC wY0my"><span class="icon-star _537e4"></span><span>4.0</span></div><div>•</div><div>26 MINS</div><div>•</div><div class="nVWSi">₹350 FOR TWO</div></div><div class="Zlfdx"><span class="icon-offer-filled _2fujs"></span><span class="sNAfh">FLAT150 off | Use FLATDEAL</span></div></div><div class="_3B2qG"><span role="button" aria-label="Open" class="_2ECk4 _24tlh">Quick View</span></div></div></a></div><div class="_3XX_A"><a href="/restaurants/thalairaj-biryani-chandra-layout-vijayanagar-bangalore-532085" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_12_oN" alt="Thalairaj Biryani" width="254" height="160"></div><div class="_3Ztcd"><div class="nA6kb">Thalairaj Biryani</div><div class="_1gURR" title="Andhra, Biryani, Hyderabadi, South Indian, Indian, Beverages">Andhra, Biryani, Hyderabadi, South Indian, Indian, Beverages</div></div><div class="_3Mn31"><div class="_9uwBC wY0my"><span class="icon-star _537e4"></span><span>4.2</span></div><div>•</div><div>30 MINS</div><div>•</div><div class="nVWSi">₹300 FOR TWO</div></div><div class="Zlfdx"><span class="icon-offer-filled _2fujs"></span><span class="sNAfh">FLAT100 off | Use FLATDEAL</span></div></div><div class="_3B2qG"><span role="button" aria-label="Open" class="_2ECk4 _24tlh">Quick View</span></div></div></a></div>'

# %%
json_data = html_to_json.convert(html1)
json_data
# Out:
# {'div': [{'_attributes': {'class': ['_3XX_A']},
#    'a': [{'_attributes': {'href': '/restaurants/burger-seigneur-indiranagar-bangalore-341895',
#       'class': ['_1j_Yo']},
#      'div': [{'_attributes': {'class': ['_1HEuF']},
#        'div': [{'_attributes': {'class': ['_3FR5S']},
#          'div': [{'_attributes': {'class': ['efp8s']},
#            'img': [{'_attributes': {'class': ['_2tuBw', '_12_oN'],
#               'alt': 'Burger Seigneur',
#               'width': '254',
#               'height': '160',
#               'src': 'https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/k4z46joj5ozirqpyww1z'}}]},
#           {'_attributes': {'class': ['IJsqo'],
#             'style': 'background: rgb(58, 60, 65); color: rgb(255, 255, 255); border-color: rgb(30, 32, 35) transparent;'},
#            'div': [{'_attributes': {'class': ['_1kXWW']},
#              '_value': 'Promoted'}]},
#           {'_attributes': {'class': ['_3Ztcd']},
#            'div': [{'_attributes': {'class': ['nA6kb']},
#              '_value': 'Burger Seigneur'},
#             {'_attributes': {'class': ['_1gURR'],
#               'title': 'American, Continental, Burgers, Beverages'},
#              '_value': 'American, Continental, Burgers, Beverages'}]},
#           {'_attributes': {'class': ['_3Mn31']},
#            'div': [{'_attributes': {'class': ['_9uwBC', 'wY0my']},
#              'span': [{'_attributes': {'class': ['icon-star', '_537e4']}},
#               {'_value': '4.3'}]},
#             {'_value': '•'},
#             {'_value': '28 MINS'},
#             {'_value': '•'},
#             {'_attributes': {'class': ['nVWSi']},
#              '_value': '₹1300 FOR TWO'}]}]},
#         {'_attributes': {'class': ['_3B2qG']},
#          'span': [{'_attributes': {'role': 'button',
#             'aria-label': 'Open',
#             'class': ['_2ECk4', '_24tlh']},
#            '_value': 'Quick View'}]}]}]}]},
#   {'_attributes': {'class': ['_3XX_A']},
#    'a': [{'_attributes': {'href': '/restaurants/raidan-authentic-arabian-restaurant-kacharakanahalli-kammanahalli-kalyan-nagar-bangalore-69720',
#       'class': ['_1j_Yo']},
#      'div': [{'_attributes': {'class': ['_1HEuF']},
#        'div': [{'_attributes': {'class': ['_3FR5S']},
#          'div': [{'_attributes': {'class': ['efp8s']},
#            'img': [{'_attributes': {'class': ['_2tuBw', '_12_oN'],
#               'alt': 'Raidan- Authentic Arabian Restaurant',
#               'width': '254',
#               'height': '160',
#               'src': 'https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/euo9db9sbvsrgi4v7lhq'}}]},
#           {'_attributes': {'class': ['_3Ztcd']},
#            'div': [{'_attributes': {'class': ['nA6kb']},
#              '_value': 'Raidan- Authentic Arabian Restaurant'},
#             {'_attributes': {'class': ['_1gURR'],
#               'title': 'Arabian, Chinese, Beverages, Mughlai'},
#              '_value': 'Arabian, Chinese, Beverages, Mughlai'}]},
#           {'_attributes': {'class': ['_3Mn31']},
#            'div': [{'_attributes': {'class': ['_9uwBC', '_2lAlc']},
#              'span': [{'_attributes': {'class': ['icon-star', '_537e4']}},
#               {'_value': '3.9'}]},
#             {'_value': '•'},
#             {'_value': '30 MINS'},
#             {'_value': '•'},
#             {'_attributes': {'class': ['nVWSi']}, '_value': '₹400 FOR TWO'}]},
#           {'_attributes': {'class': ['Zlfdx']},
#            'span': [{'_attributes': {'class': ['icon-offer-filled',
#                '_2fujs']}},
#             {'_attributes': {'class': ['sNAfh']},
#              '_value': 'FLAT100 off | Use FLATDEAL'}]}]},
#         {'_attributes': {'class': ['_3B2qG']},
#          'span': [{'_attributes': {'role': 'button',
#             'aria-label': 'Open',
#             'class': ['_2ECk4', '_24tlh']},
#            '_value': 'Quick View'}]}]}]}]},
#   {'_attributes': {'class': ['_3XX_A']},
#    'a': [{'_attributes': {'href': '/restaurants/the-dessert-zone-2nd-stage-indiranagar-bangalore-238565',
#       'class': ['_1j_Yo']},
#      'div': [{'_attributes': {'class': ['_1HEuF']},
#        'div': [{'_attributes': {'class': ['_3FR5S']},
#          'div': [{'_attributes': {'class': ['efp8s']},
#            'img': [{'_attributes': {'class': ['_2tuBw', '_12_oN'],
#               'alt': 'The Dessert Zone',
#               'width': '254',
#               'height': '160',
#               'src': 'https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/c447c9ce7d0bbe78e46141e866236762'}}]},
#           {'_attributes': {'class': ['_3Ztcd']},
#            'div': [{'_attributes': {'class': ['nA6kb']},
#              '_value': 'The Dessert Zone'},
#             {'_attributes': {'class': ['_1gURR'],
#               'title': 'Bakery, Desserts, Ice Cream, Beverages'},
#              '_value': 'Bakery, Desserts, Ice Cream, Beverages'}]},
#           {'_attributes': {'class': ['_3Mn31']},
#            'div': [{'_attributes': {'class': ['_9uwBC', 'wY0my']},
#              'span': [{'_attributes': {'class': ['icon-star', '_537e4']}},
#               {'_value': '4.2'}]},
#             {'_value': '•'},
#             {'_value': '23 MINS'},
#             {'_value': '•'},
#             {'_attributes': {'class': ['nVWSi']}, '_value': '₹200 FOR TWO'}]},
#           {'_attributes': {'class': ['Zlfdx']},
#            'span': [{'_attributes': {'class': ['icon-offer-filled',
#                '_2fujs']}},
#             {'_attributes': {'class': ['sNAfh']},
#              '_value': 'FLAT125 off | Use FLATDEAL'}]}]},
#         {'_attributes': {'class': ['_3B2qG']},
#          'span': [{'_attributes': {'role': 'button',
#             'aria-label': 'Open',
#             'class': ['_2ECk4', '_24tlh']},
#            '_value': 'Quick View'}]}]}]}]},
#   {'_attributes': {'class': ['_3XX_A']},
#    'a': [{'_attributes': {'href': '/restaurants/noto-healthy-ice-cream-guddadahalli-hebbal-rt-nagar-bangalore-567207',
#       'class': ['_1j_Yo']},
#      'div': [{'_attributes': {'class': ['_1HEuF']},
#        'div': [{'_attributes': {'class': ['_3FR5S']},
#          'div': [{'_attributes': {'class': ['efp8s']},
#            'img': [{'_attributes': {'class': ['_2tuBw', '_12_oN'],
#               'alt': 'NOTO - Healthy Ice Cream',
#               'width': '254',
#               'height': '160',
#               'src': 'https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/51bd9c7efcc0e05c614c0e0674434e62'}}]},
#           {'_attributes': {'class': ['IJsqo'],
#             'style': 'background: rgb(58, 60, 65); color: rgb(255, 255, 255); border-color: rgb(30, 32, 35) transparent;'},
#            'div': [{'_attributes': {'class': ['_1kXWW']},
#              '_value': 'Promoted'}]},
#           {'_attributes': {'class': ['_3Ztcd']},
#            'div': [{'_attributes': {'class': ['nA6kb']},
#              '_value': 'NOTO - Healthy Ice Cream'},
#             {'_attributes': {'class': ['_1gURR'],
#               'title': 'Ice Cream, Desserts'},
#              '_value': 'Ice Cream, Desserts'}]},
#           {'_attributes': {'class': ['_3Mn31']},
#            'div': [{'_attributes': {'class': ['_9uwBC', 'wY0my']},
#              'span': [{'_attributes': {'class': ['icon-star', '_537e4']}},
#               {'_value': '4.3'}]},
#             {'_value': '•'},
#             {'_value': '28 MINS'},
#             {'_value': '•'},
#             {'_attributes': {'class': ['nVWSi']}, '_value': '₹250 FOR TWO'}]},
#           {'_attributes': {'class': ['Zlfdx']},
#            'span': [{'_attributes': {'class': ['icon-offer-filled',
#                '_2fujs']}},
#             {'_attributes': {'class': ['sNAfh']},
#              '_value': '40% off | Use TRYNEW'}]}]},
#         {'_attributes': {'class': ['_3B2qG']},
#          'span': [{'_attributes': {'role': 'button',
#             'aria-label': 'Open',
#             'class': ['_2ECk4', '_24tlh']},
#            '_value': 'Quick View'}]}]}]}]}]}

# %%
base_url = "https://www.swiggy.com"
lisks = []
for i in range(4):
    x = json_data['div'][i]['a'][0]['_attributes']['href']
    print(x)
    lisks.append(base_url+x)
# Out:
# /restaurants/burger-seigneur-indiranagar-bangalore-341895
# /restaurants/raidan-authentic-arabian-restaurant-kacharakanahalli-kammanahalli-kalyan-nagar-bangalore-69720
# /restaurants/the-dessert-zone-2nd-stage-indiranagar-bangalore-238565
# /restaurants/noto-healthy-ice-cream-guddadahalli-hebbal-rt-nagar-bangalore-567207

# %%
lisks
# Out:
# ['https://www.swiggy.com/restaurants/burger-seigneur-indiranagar-bangalore-341895',
#  'https://www.swiggy.com/restaurants/raidan-authentic-arabian-restaurant-kacharakanahalli-kammanahalli-kalyan-nagar-bangalore-69720',
#  'https://www.swiggy.com/restaurants/the-dessert-zone-2nd-stage-indiranagar-bangalore-238565',
#  'https://www.swiggy.com/restaurants/noto-healthy-ice-cream-guddadahalli-hebbal-rt-nagar-bangalore-567207']

# %%
print(len(x))
print(x[0].keys())
# Out:
# 67
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4140\2217456598.py in <module>
#       1 print(len(x))
# ----> 2 print(x[0].keys())
#
# AttributeError: 'str' object has no attribute 'keys'

# %%
driver_new1 = webdriver.Chrome()
driver_new1.maximize_window()
base_url = "https://www.swiggy.com"
for ele in elements:
    html = ele.get_attribute("innerHTML")
    json = html_to_json.convert(html)
    for i in range(4):
        x = json['div'][i]['a'][0]['_attributes']['href']
        link = base_url + x
        driver_new.get(link)
        time.sleep(5)
        
    
    
# for link in lisks:
    

#     driver_new.get(link)
#     time.sleep(5)
driver_new.close

# %%
import re

# Extract the restaurant names using regular expression
restaurant_names = re.findall('<div class="nA6kb">(.*?)</div>', html1)

# Print the restaurant names
print(restaurant_names)
# Out:
# ["Leon's - Burgers &amp; Wings (Leon Grill)", 'Meghana Foods', 'Hotel Empire', 'Kannur Food Point']

# %% [markdown]
# # Html List

# %%
# Initialize an empty list
html_list = []

# Loop through the elements and get their innerHTML
for ele in elements:
    html = ele.get_attribute("innerHTML")
    # Append the innerHTML to the list
    html_list.append(html)

# Print the list of innerHTML
print(html_list)
# Out:
# ['<div class="_3XX_A"><a href="/restaurants/burger-seigneur-indiranagar-bangalore-341895" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_2tuBw _12_oN" alt="Burger Seigneur" width="254" height="160" src="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/k4z46joj5ozirqpyww1z"></div><div class="IJsqo" style="background: rgb(58, 60, 65); color: rgb(255, 255, 255); border-color: rgb(30, 32, 35) transparent;"><div class="_1kXWW">Promoted</div></div><div class="_3Ztcd"><div class="nA6kb">Burger Seigneur</div><div class="_1gURR" title="American, Continental, Burgers, Beverages">American, Continental, Burgers, Beverages</div></div><div class="_3Mn31"><div class="_9uwBC wY0my"><span class="icon-star _537e4"></span><span>4.3</span></div><div>•</div><div>28 MINS</div><div>•</div><div class="nVWSi">₹1300 FOR TWO</div></div></div><div class="_3B2qG"><span role="button" aria-label="Open" class="_2ECk4 _24tlh">Quick View</span></div></div></a></div><div class="_3XX_A"><a href="/restaurants/raidan-authentic-arabian-restaurant-kacharakanahalli-kammanahalli-kalyan-nagar-bangalore-69720" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_2tuBw _12_oN" alt="Raidan- Authentic Arabian Restaurant" width="254" height="160" src="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/euo9db9sbvsrgi4v7lhq"></div><div class="_3Ztcd"><div class="nA6kb">Raidan- Authentic Arabian Restaurant</div><div class="_1gURR" title="Arabian, Chinese, Beverages, Mughlai">Arabian, Chinese, Beverages, Mughlai</div></div><div class="_3Mn31"><div class="_9uwBC _2lAlc"><span class="icon-star _537e4"></span><span>3.9</span></div><div>•</div><div>30 MINS</div><div>•</div><div class="nVWSi">₹400 FOR TWO</div></div><div class="Zlfdx"><span class="icon-offer-filled _2fujs"></span><span class="sNAfh">FLAT100 off | Use FLATDEAL</span></div></div><div class="_3B2qG"><span role="button" aria-label="Open" class="_2ECk4 _24tlh">Quick View</span></div></div></a></div><div class="_3XX_A"><a href="/restaurants/the-dessert-zone-2nd-stage-indiranagar-bangalore-238565" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_2tuBw _12_oN" alt="The Dessert Zone" width="254" height="160" src="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/c447c9ce7d0bbe78e46141e866236762"></div><div class="_3Ztcd"><div class="nA6kb">The Dessert Zone</div><div class="_1gURR" title="Bakery, Desserts, Ice Cream, Beverages">Bakery, Desserts, Ice Cream, Beverages</div></div><div class="_3Mn31"><div class="_9uwBC wY0my"><span class="icon-star _537e4"></span><span>4.2</span></div><div>•</div><div>23 MINS</div><div>•</div><div class="nVWSi">₹200 FOR TWO</div></div><div class="Zlfdx"><span class="icon-offer-filled _2fujs"></span><span class="sNAfh">FLAT125 off | Use FLATDEAL</span></div></div><div class="_3B2qG"><span role="button" aria-label="Open" class="_2ECk4 _24tlh">Quick View</span></div></div></a></div><div class="_3XX_A"><a href="/restaurants/noto-healthy-ice-cream-guddadahalli-hebbal-rt-nagar-bangalore-567207" class="_1j_Yo"><div class="_1HEuF"><div class="_3FR5S"><div class="efp8s"><img class="_2tuBw _12_oN" alt="NOTO - Healthy Ice Cream" width="254" height="160" src="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_508,h_320,c_fill/51bd9c7efcc0e05c614c0e0674434e62"></div><div class="IJsqo" style="background: rgb(58, 60, 65); color: rgb(255, 255, 255); border-color: rgb(30, 32, 35) transparent;"><div class="_1kXWW">Promoted</div></div><div class="_3Ztcd"><div class="nA6kb">NOTO - Healthy Ice Cream</div><div class="_1gURR" title="Ice Cream, Desserts">Ice Cream, Desserts</div></div><div class="_3Mn31"><div class="_9uwBC wY0my"><span class="icon-star _537e4"></span><span>4.3</span></div><div>•</div><div>28 MINS</div><div>•</div><div class="nVWSi">₹250 FOR TWO</div></div><d ...

# %%
import re

# List to store the restaurant names
restaurant_names = []

# Loop through the html strings and extract the restaurant names
for html in html_list:
    names = re.findall('<div class="nA6kb">(.*?)</div>', html)
    restaurant_names.extend(names)

# Print the list of restaurant names
print(restaurant_names)
# Out:
# ["Leon's - Burgers &amp; Wings (Leon Grill)", 'Biryani Pot', 'Burger King', 'Kannur Food Point', 'Burger Seigneur', 'Sri Punjabi Dhaba', 'Hotel Empire', "Auntie Fung's", 'Pizza Hut', 'Royal Restaurant', 'Imperio Restaurant', "La Pino'z Pizza", 'Shanghai House', 'Meghana Foods', 'New Taj Darbar', 'Al-Bek', 'NOTO - Healthy Ice Cream', 'IFC', 'Chopstick', 'Shapana dhaba', 'Rotti Walla', 'Biryani &amp; Bowls', 'Le MoMo', "McDonald's", 'NEW Mahesh friends food center', 'Chicking', 'Rollsking', 'Namaste', 'Onesta', 'Madeena Hotel', 'KFC', 'Ambur Dum Biriyani', 'Kabab King', 'Hamza hotel', 'Donne Biryani Adda', 'Easy Bites by Hotel Empire', 'Imperio Juice and Ice creams', 'Lassi and Juice', 'Five Star Chicken', 'Rolls On Wheels', 'Sree Banashankari Donne Biryani', 'Sri Ram Bhojanalay', 'Marwadi Chaat &amp; Tiffin Services Shanti nagar', 'Royal Donne Biryani', "Smitha's Kitchen", 'Late Night', 'Maharaja Military Canteen-Donne Biryani', 'Chinese BAE', 'The Bowl Company', 'Om meals and paratha junction', 'Om Sai Ram Food Junction', 'Lajawaab', 'Dum Biryani Hub', "Domino's Pizza", "Wendy's Burgers", 'Main Lassi Shop', 'Savoury Restaurant', 'Crispy Studio', 'Imperial Restaurant', 'Thalairaj Biryani', 'Dairy Day Ice Creams', 'Polar Bear Ice Cream Sundaes', 'HUNGRAMA RESTAURANT', 'Craving O Clock', 'HFC Call Me Kabab', 'TANDOORWAALA', 'The Meals Junction', 'Pizza Plutos', 'THE FRITTER COMPANY', '7 Plates', 'Sultan dum biryani', 'NARMADA CHAIN OF RESTAURANT', "Vinny's", 'Meghduth Biryanis', 'Phoenix pizza', 'Savoury Seashell Restaurant', 'Biryani Khazana', 'Tandoori Merchant', 'Fresh Bites', 'Shawarma On Wheels', 'Kolkata Durbar', 'Rajasthani Taj restaurant', 'Oven Story Pizza', 'Chinese Wok', 'The Belgian Waffle Co.', 'Olio - The Wood Fired Pizzeria', '89 Express Dhaba', 'Sreeraj Lassi Bar 1973s\t', 'Momoz', 'Biryani Mount', 'MAFUQ BIRYANI', 'Alba Cafe', 'WarmOven Cake &amp; Desserts', 'Istah - The Mediterranean Way', 'Coorg Spicy Kadai', 'Grill Shawarma Cafe', 'Indori Poha', 'Sharief Bhai', 'The royal burgers', 'New kadai restaurant', 'Andhra Meals Express', 'Wow! China', 'Lucknow Express', 'Swad Restaurant', 'Le Arabia Restaurant', 'METRO FOOD', 'BURGER ZONE', 'Madeena Aroma Biryani', 'Ember &amp; Frost', 'Daily Chinese', 'LICIOUS PIZZA', 'Khan Saheb Grills and Rolls', 'The Punjabi kitchen', 'Meat and Eat', 'Malabar Cafe', 'Bismillah hotel A1', 'Foodism.in', 'temperature', '24/7 JUICE N SNACKS HUB', 'Shri Nellore Mess', 'XO Belgian Waffle', 'Big Bowl (Big Bowl Company)', 'Chinese Trail', 'Vaigai Vilas', 'TEXAS BURGERS', 'Samosa Party', 'Sardarji Londonwaley', 'Burger In Moon', 'Swiss Cream - Ice Creams and More', 'GFC Kebabs &amp; Biryani', 'Al Taj', 'Biryani Hotel', 'California Burrito', 'bihari express', "Flavor's Season", 'Nandhana Palace', 'CakeZone', 'Royal Biryani Kitchen', 'Bihar ki rasoi', 'Darjeeling Hot Momos', 'The Biryani Life', 'Empire Juices and Desserts', 'Krispy Kreme', 'Mallu family Restaurant', 'The Best Snacks Adda', 'California burger village', 'The Dessert Zone', 'BURGER AND BEANS', 'Kwality Walls Frozen Dessert and Ice Cream Shop', 'The Good Bowl', 'Snacks Corner', 'Zinger crunch', 'Faasos - Wraps &amp; Rolls', 'WEDEL FOOD', 'The Pastry Zone\t', 'Lassi Shop', "Crusto's - Cheese Burst Pizza", 'Asha Sweet Center', "Dragon's Kitchen", 'Cream Stone Ice Cream', 'Backyard Burgers and Grill', 'Biryani Blues', 'Hunger Saviour', 'Ghar Wali Khana', 'KOLKATA BIRYANI POINT', 'Ghar Ki Rasoi', 'The Kolkata Katiroll', 'EASY BITES BY EMPIRE', 'Bombay Kulfi', 'Behrouz Biryani', 'Samrat Donne Biriyani', 'Tamilian Lunch House Since 1973', 'The Bangalore Creamery', 'Midnight Eats', 'Nandhini Deluxe', 'Old Town Pizzeria', 'Coffee and Cream', 'Baskin Robbins', 'Momo Zone - The Momo Company', 'Keventers Ice Cream', 'What A Food', 'PUNJAB KITCHEN', 'Keventers - Milkshakes &amp; Desserts', 'Wow! Momo', 'Chai Corner', 'Sweet Bake - Cake &amp; Desserts', 'Yumlane Pizza', 'Baba Ka Khana', 'LunchBox - Meals and Thalis', 'Karavali Family Restaura ...

# %%
import pandas as pd

# Create a dictionary with the restaurant names
data = {'Restaurant Names': restaurant_names}

# Convert the dictionary into a dataframe
df10 = pd.DataFrame(data)

# Print the dataframe
print(df10)
# Out:
#                               Restaurant Names
# 0    Leon's - Burgers &amp; Wings (Leon Grill)
# 1                                  Biryani Pot
# 2                                  Burger King
# 3                            Kannur Food Point
# 4                              Burger Seigneur
# ..                                         ...
# 682                             signature cafe
# 683                          Lassi forever@BLR
# 684                              Rich Sandwich
# 685                              Munchous Cafe
# 686                                Panda Momos
#
# [687 rows x 1 columns]

# %%
import re

# List to store the restaurant ratings
ratings = []

# Loop through the HTML strings and extract the ratings
for html in html_list:
    rating = re.findall('<span class="icon-star _537e4"></span><span>(.*?)</span>', html)
    if rating:
        ratings.append(rating[0])
    else:
        ratings.append(' ')
# Create a dictionary with the ratings
data = {'Rating': ratings}

# Convert the dictionary into a dataframe
df11 = pd.DataFrame(data)

# Print the dataframe
print(df11)
# Out:
#     Rating
# 0      4.3
# 1      4.4
# 2      4.0
# 3      4.3
# 4      3.9
# ..     ...
# 286     --
# 287     --
# 288     --
# 289    4.3
# 290    3.0
#
# [291 rows x 1 columns]

# %%
import re
import pandas as pd

# List to store the prices for two
price_for_two = []

# Loop through the html strings and extract the prices for two
for html in html_list:
    price = re.findall('<div class="nVWSi">(.*?)</div>', html)
    if price:
        price_for_two.append(price[0])

# Create a dictionary with the prices for two
data = {'Price for Two': price_for_two}

# Convert the dictionary into a dataframe
df12 = pd.DataFrame(data)
df12

# Print the price column
#print(df12['Price for Two'])
# Out:
#      Price for Two
# 0     ₹300 FOR TWO
# 1    ₹1200 FOR TWO
# 2     ₹400 FOR TWO
# 3     ₹700 FOR TWO
# 4     ₹600 FOR TWO
# ..             ...
# 286   ₹350 FOR TWO
# 287   ₹300 FOR TWO
# 288   ₹200 FOR TWO
# 289   ₹200 FOR TWO
# 290   ₹100 FOR TWO
#
# [291 rows x 1 columns]

# %%
import re
import pandas as pd

# List to store the cuisines
cuisines = []

# Loop through the HTML strings and extract the cuisine information
for html in html_list:
    cuisine_list = re.findall('<div class="_1gURR" title="(.*?)">', html)
    cuisine = ", ".join(cuisine_list)
    cuisines.append(cuisine)

# Create a dictionary with the cuisines
data = {'Cuisines': cuisines}

# Convert the dictionary into a dataframe
df13 = pd.DataFrame(data)

# Print the dataframe
print(df13)
# Out:
#                                               Cuisines
# 0    Pan-Asian, Continental, North Indian, Desserts...
# 1    South Indian, Mexican, American, Salads, Conti...
# 2    American, Desserts, Continental, Italian, Burg...
# 3    Andhra, Biryani, Chinese, North Indian, South ...
# 4    Andhra, Biryani, Chinese, North Indian, South ...
# ..                                                 ...
# 343  Indian, Tandoor, Pastas, Asian, Desserts, Pizz...
# 344  Beverages, Ice Cream, Continental, Desserts, J...
# 345  Biryani, Chinese, Indian, Chinese, Continental...
# 346  Ice Cream, Beverages, Desserts, Desserts, Beve...
# 347                              Combo, Indian, Snacks
#
# [348 rows x 1 columns]

# %%
df.to_excel('my_restaurants.xlsx', index=False)

# %%
import re
import pandas as pd

# List to store the restaurant data
restaurant_data = []

# Loop through the html strings and extract the restaurant data
for html in html_list:
#     restaurant_ids = re.findall('data-rest-id="(.*?)"', html)
#     restaurant_links = re.findall('<a href="(.*?)">', html)
    name = re.findall('<div class="nA6kb">(.*?)</div>', html)
    rating = re.findall('<span class="icon-star _537e4"></span><span>(.*?)</span>', html)
    cusins = re.findall('<div class="_1gURR" title="(.*?)">', html)
    price = re.findall('<div class="nVWSi">(.*?)</div>', html)
    delivery_time = re.findall('<div>(\d+) MINS</div>', html)
    link=
    
    # If price or cusins not found, set it to empty string
    if not price:
        price = [""]
    if not cusins:
        cusins = [""]
        
    # Add the restaurant data to the list
    restaurant_data.append([name[0], rating[0], cusins[0], price[0], delivery_time[0]])

# Create a dataframe from the restaurant data
df = pd.DataFrame(restaurant_data, columns=['Restaurant Name', 'Rating', 'Cusins', 'Price for Two', 'Delivery Time'])

# Extract the list of restaurant names from the dataframe
restaurant_names = df['Restaurant Name'].tolist()

# Print the list of restaurant names
print(restaurant_names)
# Out:
# ['The Bowl Company', 'Puliyogare Point', 'Truffles', 'Nandhini Deluxe', 'Nandhini Deluxe', 'Keventers Ice Cream', 'Sea Spice Multicuisine Restaurant', 'Pure Veg Meals by Lunchbox', 'Vijayalakshmi', 'Ambur Star Briyani Since 1890', 'Rotti Walla', 'Tomba kitchen', 'Corner House Ice Cream', 'N R Donne Biriyani', 'Sultan Rolls &amp; Sandwiches', 'Chowman', 'Anand Sweets &amp; Savouries', 'K.Iyer Mess ', 'Rajdhani', 'ONESTA', 'SMOOR', 'Deja Bowl', 'Davanagere Benne Dose', 'Biriyani Paradise (Dakshin)', 'Chickpet Donne Biryani House', 'Sagar Delicacy', 'Polar Bear Ice Cream Sundaes', 'Beijing Bites', 'MTR', 'Tapri By The Corner', "Kapoor's Cafe", 'Shahi Family Restaurant', 'Kwality Walls Frozen Dessert and Ice Cream Shop', 'Punjabi Nawabi', 'Samosa Party', 'Magnolia Bakery', 'Bangalore Thindies', 'santhanam sweets', 'Holige Mane', 'Paratha Envy', 'Main Lassi Shop', 'Sandwich Guru', 'Aubree', 'Faasos - Wraps &amp; Rolls', 'Sai cafe veg', 'Hotel Bilal Biriyani Centre', 'Kaippunnyam Restaurant', 'Krishnam Veg', "Polamma's Mess", 'Maharaja Military Canteen-Donne Biryani', 'Gokul Veg', 'Taco Bell', 'Sagar fast food', 'NEW PRAKRITI DELUXE', 'Hotel Chandrika', 'Rooftop Cafe', 'Great Indian Khichdi by EatFit', 'Karnataka state CO-OPERATIVE fisheries federation', 'Swiss Cream - Ice Creams and More', 'IDC Kitchen', 'LunchBox - Meals and Thalis', 'Ryu Ramen Co.', 'Delicacy', 'The Bengal Club', 'BOSS Burger', 'Trupthi Ahaar', 'Bombay Kulfis', 'THAR the taste of Rajasthan', 'Le Gateau - The Cake Shop', 'FlavorVille', 'Shyam Mishra Juice Center', 'Sri Krishna Nandagokula Veg', 'Sree Krishna Kafe', 'Green Cravings', 'TrueCakes - Fresh | Eggless | Cakes', 'Maggi Mane', 'Kitchens of China', 'The SnackStop(Eswaris Homemade snacks)', 'Brik Oven', 'All Saints Bakery', 'Sanman Restaurant', 'The tasty planet', 'Raj Restaurant', 'Lush - Renaissance Bengaluru Race Course Hotel By Marriott.', 'Dwarkamai Pure Veg Restaurant', 'Bowl Soul', 'Momo Rice Noodles', 'SMOOR', 'By 2 Coffee', 'Hive Honey Cake', 'Keventers Ice Cream', 'Cupcake Bliss Cake &amp; Desserts', 'Avanthi - Aromas of Andhra', 'Davanagere Benne Dose', 'NEW AMBUR SPECIAL DUM BIRIYANI', 'Healthy Chef', 'Boba Tree', 'NAMMUR JOINT', 'Grameen Kulfi', 'Aaliyar Ambur Dum Biryani', 'Falhari - A Fruitful Habit', 'Chacha Ka Chaat', 'Sattuani', 'ONLY BREADS', 'Tadka Singh', "Nirula's", 'KORIKEN', 'Lavonne', 'Carols Pastries &amp; Bakers', 'Burger Seigneur', 'BISMILLAH HOTEL', 'Oh! Calcutta', 'Uttar Karnataka Jolad Rotti Matu Chapati Angadi', 'AMMAN PAROTTA PLAZA', 'CHOLAY', 'Hot Momo Darjeeling Style', 'Chinita Real Mexican Food', 'Chillies', 'Kabab Korner', 'Plan B', 'Robin Brown Ice Cream', 'Munchies', 'Village Donne Biriyani', 'COASTAL MACHALI CO', 'Tandoor Hut', 'Habibi Falafel', 'JUICE BREWS', 'Khichdi Kahani', 'Harshi Super Sandwich', 'Ovenfresh Cakes and Desserts', 'Fries Box', "Bhadra's Kitchen", 'Chaayos Chai+Snacks=Relax', 'Goodness To Go', "Hotel Tom's Restaurant", 'Oki Poki - Sushi, Dimsums &amp; More', 'Five Star Chicken', 'Ninhao Asian Kitchen', 'Biergarten Brewery &amp; Kitchen', 'Prasuma Momo Kitchen', 'Sri sai ram juice and chats', 'Sultans of Spice', 'PVR Cafe', 'Happy Belly Bakes- Cakes and Desserts', 'GO NAATI', 'CHURMUR CHAAT CO', 'SHIVAS MILITARY HOTEL', 'The Ganache Factory - Cakes &amp; Desserts', 'Kabab Magic Roll', 'M/s. SUKHSAGAR HOTEL GANDHINAGAR', 'Nizaams Kaati Rolls', "Italian BOB Pizza's", 'Apna Ghar', 'Cafe Reset', 'Side Dish', 'Blue Tokai Coffee Roasters', 'Cookie Man', 'The Brooklyn Creamery - Healthy Ice Cream', 'Cotton Candy Station', 'Matsya', "Thin Tony's Pizza", 'ITC Sunfeast Baked Creations', 'Asia Seven - Sizzling Chinese', 'Deja Bowl', 'Umpire chicken county', 'Paratha Box - Desi Punjabi Meals', 'SEA MEEN RESTAURANT', 'V Cafe - Meals By PVR', 'Miami shakes &amp; More', 'The tasty planet', 'Sln tiffin room muddanna hotel', 'The Chaat Cult', 'The Momo Co.', 'La Fresca Pasta', 'Vegan kitchen', 'LOVE AND CRUMBLE', 'BOBBY KA VEG DHABA (Amritsarwala)', 'World Of Chinese ...

# %%
df
# Out:
#                                Restaurant Name Rating  \
# 0    Leon's - Burgers &amp; Wings (Leon Grill)    4.3
# 1                              Burger Seigneur    4.4
# 2                               Shanghai House    4.0
# 3                                      Rahhams    4.3
# 4                                    Pizza Hut    3.9
# ..                                         ...    ...
# 286                             CINDY'S CLUCKS     --
# 287                          Uncle Johnny Cafe     --
# 288                      Sri venkatagiri hotel     --
# 289                                   SVI Food    4.3
# 290                                  Breakfast    3.0
#
#                                                 Cusins  Price for Two  \
# 0    American, Snacks, Turkish, Portuguese, Contine...   ₹300 FOR TWO
# 1                     American, Continental, Beverages  ₹1200 FOR TWO
# 2    Chinese, Thai, Seafood, Asian, Healthy Food, B...   ₹400 FOR TWO
# 3    Biryani, Mughlai, North Indian, Kebabs, Chines...   ₹700 FOR TWO
# 4                                               Pizzas   ₹600 FOR TWO
# ..                                                 ...            ...
# 286                      North Indian, Tandoor, Kebabs   ₹350 FOR TWO
# 287      Continental, Chinese, North Indian, Beverages   ₹300 FOR TWO
# 288                                            Chinese   ₹200 FOR TWO
# 289                                       North Indian   ₹200 FOR TWO
# 290            Juices, Healthy Food, Beverages, Snacks   ₹100 FOR TWO
#
#     Delivery Time
# 0              30
# 1              27
# 2              29
# 3              33
# 4              26
# ..            ...
# 286            32
# 287            43
# 288            35
# 289            38
# 290            37
#
# [291 rows x 5 columns]

# %%
df.to_excel("restaurant_datafinal4823.xlsx", index=False)

# %%
import pandas as pd

# Assuming you have four dataframes df1, df2, df3, df4
# Concatenate the four dataframes vertically (i.e. stack them on top of each other)
merged_df = pd.concat([df10, df11, df12, df13], axis=1)
merged_df

# Reset the index of the merged dataframe
#merged_df = merged_df.reset_index(drop=True)
# Out:
#           Restaurant Names Rating Price for Two  \
# 0         The Bowl Company    4.4  ₹300 FOR TWO
# 1            Meghana Foods    4.5  ₹150 FOR TWO
# 2        Kannur Food Point    4.4  ₹450 FOR TWO
# 3             Hotel Empire    4.2  ₹500 FOR TWO
# 4         Puliyogare Point    4.2  ₹500 FOR TWO
# ...                    ...    ...           ...
# 1385         Kunafa Lounge    NaN           NaN
# 1386               Emperor    NaN           NaN
# 1387        Mahi Bakehouse    NaN           NaN
# 1388           HOME COOKED    NaN           NaN
# 1389  HOB-House of Bhatura    NaN           NaN
#
#                                                Cuisines
# 0     Pan-Asian, Continental, North Indian, Desserts...
# 1     South Indian, Mexican, American, Salads, Conti...
# 2     American, Desserts, Continental, Italian, Burg...
# 3     Andhra, Biryani, Chinese, North Indian, South ...
# 4     Andhra, Biryani, Chinese, North Indian, South ...
# ...                                                 ...
# 1385                                                NaN
# 1386                                                NaN
# 1387                                                NaN
# 1388                                                NaN
# 1389                                                NaN
#
# [1390 rows x 4 columns]

# %%
merged_df.to_excel("restaurant_datafinal.xlsx", index=False)

# %%
driver_new = webdriver.Chrome()
driver_new.maximize_window()
base_url = "https://www.swiggy.com"

for j in range(1):
    html = elements[i].get_attribute("innerHTML")
    json = html_to_json.convert(html)
    for i in range(4):
        x = json['div'][i]['a'][0]['_attributes']['href']
        link = base_url + x
        driver_new.get(link)
        Restaurant_etra = []
        data = driver.find_elements(by=By.CLASS_NAME, value='qSD35_2NLYT12')
        for page in range(1):
            
            Category = data.find_element(by=By.CLASS_NAME, value='styles_headerNestedTitle__1PFSM')
            Restaurant_details = {'Category_':Category}
            Restaurant_etra.append(Restaurant_details)
            time.sleep(5)
    
driver_new.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11992\2332993334.py in <module>
#      14         for page in range(1):
#      15
# ---> 16             Category = data.find_element(by=By.CLASS_NAME, value='styles_headerNestedTitle__1PFSM')
#      17             Restaurant_details = {'Category_':Category}
#      18             Restaurant_etra.append(Restaurant_details)
#
# AttributeError: 'list' object has no attribute 'find_element'

# %%
driver_new1 = webdriver.Chrome()
driver_new1.maximize_window()
base_url = "https://www.swiggy.com"
for i in range(1):
    html = elements[i].get_attribute("innerHTML")
    json = html_to_json.convert(html)
    for j in range(4):
        x = json['div'][j]['a'][0]['_attributes']['href']
        link = base_url + x
        driver_new1.get(link)
        time.sleep(5)
driver_new1.close()

# %%
Restaurant_etra

# %%
Restaurant_details

# %%
driver.find_element(by=By.XPATH, value='//*[@id="location"]')
//*[@id="all_restaurants"]/div/div[2]/div[1]/div/div[1]/div[1]/a/div/div[1]/div[3]/div[1]

# %%
for lll in range(len(lisks)):
    print(lisks[lll])
# Out:
# https://www.swiggy.com/restaurants/wok-china-kodigehalli-indiranagar-bangalore-410242
# https://www.swiggy.com/restaurants/indori-poha-1st-block-koramangala-bangalore-162807
# https://www.swiggy.com/restaurants/lassi-shop-3rd-stage-banashankari-bangalore-609510
# https://www.swiggy.com/restaurants/ember-and-frost-jyoti-nivas-college-rd-koramangala-bangalore-678320

# %%
import requests
from bs4 import BeautifulSoup

# Assuming you have a list of links called `links_list`
html_dict = {}

for link in lisks:
    response = requests.get(link)
    soup = BeautifulSoup(response.content, 'html.parser')
    html_dict[link] = str(soup)

print(html_dict)
# Out:
# {'https://www.swiggy.com/restaurants/burger-seigneur-indiranagar-bangalore-341895': '<html class="fonts-loaded" lang="en">\n<head>\n<link href="https://res.cloudinary.com" rel="preconnect"/>\n<link href="https://res.cloudinary.com" rel="dns-prefetch"/>\n<meta content="text/html; charset=utf-8" http-equiv="Content-type"/>\n<meta charset="utf-8"/>\n<meta content="width=device-width, initial-scale=1.0" name="viewport"/>\n<title>\n      Order food online from India\'s best food delivery service. Order from\n      restaurants near you\n    </title>\n<meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>\n<link href="https://res.cloudinary.com/swiggy/image/upload/portal/c/icon-192x192.png" rel="icon" sizes="192x192"/>\n<link href="https://res.cloudinary.com/swiggy/image/upload/portal/c/icon-192x192.png" rel="apple-touch-icon" sizes="192x192"/>\n<link href="https://res.cloudinary.com/swiggy/image/upload/portal/c/favicon-16x16.ico" rel="icon" type="image/x-icon"/>\n<link href="https://res.cloudinary.com/swiggy/image/upload/portal/c/favicon-32x32.ico" rel="shortcut icon" type="image/x-icon"/>\n<link href="https://res.cloudinary.com/swiggy/image/upload/portal/c/favicon-96x96.png" rel="icon" type="image/png"/>\n<link href="https://res.cloudinary.com/swiggy/image/upload/portal/c/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>\n<style type="text/css">\n      html {\n        line-height: 1.15;\n        -ms-text-size-adjust: 100%;\n        -webkit-text-size-adjust: 100%;\n      }\n      body {\n        margin: 0;\n      }\n      article,\n      aside,\n      footer,\n      header,\n      nav,\n      section {\n        display: block;\n      }\n      h1 {\n        font-size: 2em;\n        margin: 0.67em 0;\n      }\n      figcaption,\n      figure,\n      main {\n        display: block;\n      }\n      figure {\n        margin: 1em 40px;\n      }\n      hr {\n        box-sizing: content-box;\n        height: 0;\n        overflow: visible;\n      }\n      pre {\n        font-family: monospace, monospace;\n        font-size: 1em;\n      }\n      a {\n        background-color: transparent;\n        -webkit-text-decoration-skip: objects;\n      }\n      abbr[title] {\n        border-bottom: none;\n        text-decoration: underline;\n        text-decoration: underline dotted;\n      }\n      b,\n      strong {\n        font-weight: inherit;\n        font-weight: bolder;\n      }\n      code,\n      kbd,\n      samp {\n        font-family: monospace, monospace;\n        font-size: 1em;\n      }\n      dfn {\n        font-style: italic;\n      }\n      mark {\n        background-color: #ff0;\n        color: #000;\n      }\n      small {\n        font-size: 80%;\n      }\n      sub,\n      sup {\n        font-size: 75%;\n        line-height: 0;\n        position: relative;\n        vertical-align: baseline;\n      }\n      sub {\n        bottom: -0.25em;\n      }\n      sup {\n        top: -0.5em;\n      }\n      audio,\n      video {\n        display: inline-block;\n      }\n      audio:not([controls]) {\n        display: none;\n        height: 0;\n      }\n      img {\n        border-style: none;\n      }\n      svg:not(:root) {\n        overflow: hidden;\n      }\n      button,\n      input,\n      optgroup,\n      select,\n      textarea {\n        font-family: sans-serif;\n        font-size: 100%;\n        line-height: 1.15;\n      }\n      button,\n      input {\n        overflow: visible;\n      }\n      button,\n      select {\n        text-transform: none;\n      }\n      [type="reset"],\n      [type="submit"],\n      button,\n      html [type="button"] {\n        -webkit-appearance: button;\n      }\n      [type="button"]::-moz-focus-inner,\n      [type="reset"]::-moz-focus-inner,\n      [type="submit"]::-moz-focus-inner,\n      button::-moz-focus-inner {\n        border-style: none;\n        padding: 0;\n      }\n      [type="button"]:-moz-focusring,\n      [type="reset"]:-moz-focusring,\n      [typ ...

# %%
# find the category element based on its class name
category_element = soup.find_all(class_='main_container__3QMrw')

# get the class name of the category element
category_class_name = category_element['class'][0]

print(category_class_name)

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
start = time.time()




service = Service('chromedriver.exe')


driver = webdriver.Chrome(service=service)

# %%
link = 'https://www.swiggy.com/restaurants/wok-china-kodigehalli-indiranagar-bangalore-410242'

# It will open the website on new chrome window
driver.get(link)

# %%
import re
import pandas as pd

# List to store the restaurant data
restaurant_data = []

# Loop through the html strings and extract the restaurant data
for html in html_list:
#     restaurant_ids = re.findall('data-rest-id="(.*?)"', html)
    restaurant_links = re.findall('<a href="(.*?)">', html)
    name = re.findall('<div class="nA6kb">(.*?)</div>', html)
    rating = re.findall('<span class="icon-star _537e4"></span><span>(.*?)</span>', html)
    cusins = re.findall('<div class="_1gURR" title="(.*?)">', html)
    price = re.findall('<div class="nVWSi">(.*?)</div>', html)
    delivery_time = re.findall('<div>(\d+) MINS</div>', html)
    
    # If price or cusins not found, set it to empty string
    if not price:
        price = [""]
    if not cusins:
        cusins = [""]
        
    # Add the restaurant data to the list
    restaurant_data.append([restaurant_links[0],name[0], rating[0], cusins[0], price[0], delivery_time[0]])

# Create a dataframe from the restaurant data
df88 = pd.DataFrame(restaurant_data, columns=['Link','Restaurant Name', 'Rating', 'Cusins', 'Price for Two', 'Delivery Time'])
df88
# Out:
#                                                   Link  \
# 0    /restaurants/leons-burgers-and-wings-leon-gril...
# 1    /restaurants/burger-seigneur-st-marks-road-ban...
# 2    /restaurants/shanghai-house-bairasandra-r-t-na...
# 3    /restaurants/rahhams-pulikeshi-nagar-frazer-to...
# 4    /restaurants/pizza-hut-oshngnessy-road-langfor...
# ..                                                 ...
# 286  /restaurants/cindys-clucks-tavarekere-main-rd-...
# 287  /restaurants/uncle-johnny-cafe-6th-block-koram...
# 288  /restaurants/sri-venkatagiri-hotel-manjunath-n...
# 289  /restaurants/svi-food-jogupalya-halasuru-banga...
# 290  /restaurants/breakfast-shivajinagar-no-55-cock...
#
#                                Restaurant Name Rating  \
# 0    Leon's - Burgers &amp; Wings (Leon Grill)    4.3
# 1                              Burger Seigneur    4.4
# 2                               Shanghai House    4.0
# 3                                      Rahhams    4.3
# 4                                    Pizza Hut    3.9
# ..                                         ...    ...
# 286                             CINDY'S CLUCKS     --
# 287                          Uncle Johnny Cafe     --
# 288                      Sri venkatagiri hotel     --
# 289                                   SVI Food    4.3
# 290                                  Breakfast    3.0
#
#                                                 Cusins  Price for Two  \
# 0    American, Snacks, Turkish, Portuguese, Contine...   ₹300 FOR TWO
# 1                     American, Continental, Beverages  ₹1200 FOR TWO
# 2    Chinese, Thai, Seafood, Asian, Healthy Food, B...   ₹400 FOR TWO
# 3    Biryani, Mughlai, North Indian, Kebabs, Chines...   ₹700 FOR TWO
# 4                                               Pizzas   ₹600 FOR TWO
# ..                                                 ...            ...
# 286                      North Indian, Tandoor, Kebabs   ₹350 FOR TWO
# 287      Continental, Chinese, North Indian, Beverages   ₹300 FOR TWO
# 288                                            Chinese   ₹200 FOR TWO
# 289                                       North Indian   ₹200 FOR TWO
# 290            Juices, Healthy Food, Beverages, Snacks   ₹100 FOR TWO
#
#     Delivery Time
# 0              30
# 1              27
# 2              29
# 3              33
# 4              26
# ..            ...
# 286            32
# 287            43
# 288            35
# 289            38
# 290            37
#
# [291 rows x 6 columns]

# %%
    restaurant_data.append([restaurant_links[0],name[0], rating[0], cusins[0], price[0], delivery_time[0]])

# Create a dataframe from the restaurant data
df88 = pd.DataFrame(restaurant_data, columns=['Link','Restaurant Name', 'Rating', 'Cusins', 'Price for Two', 'Delivery Time'])
df88

# %%
import re
import pandas as pd

# List to store the restaurant data
restaurant_data5 = []

# Loop through the html strings and extract the restaurant data
for html in html_list:
#     restaurant_ids = re.findall('data-rest-id="(.*?)"', html)
    restaurant_links = re.findall('<a href="(.*?)">', html)
    name = re.findall('<div class="nA6kb">(.*?)</div>', html)
    
    # Add the restaurant data to the list
    restaurant_data5.append([restaurant_links[0],name[0]])
    restaurant_data5.append([restaurant_links[1],name[1]])
    restaurant_data5.append([restaurant_links[2],name[2]])


# Create a dataframe from the restaurant data
dfvv = pd.DataFrame(restaurant_data5, columns=['Link','RestraNAme'])
dfvv
# Out:
#                                                   Link  \
# 0    /restaurants/leons-burgers-and-wings-leon-gril...
# 1    /restaurants/biryani-pot-maruti-nagar-btm-layo...
# 2    /restaurants/burger-king-tasker-town-shivaji-n...
# 3    /restaurants/burger-seigneur-st-marks-road-ban...
# 4    /restaurants/sri-punjabi-dhaba-cashier-layout-...
# ..                                                 ...
# 511  /restaurants/popcorn-me-keb-colony-btm-layout-...
# 512  /restaurants/signature-cafe-shivanagar-basaves...
# 513  /restaurants/rich-sandwich-2nd-stage-btm-layou...
# 514  /restaurants/munchous-cafe-1st-stage-btm-layou...
# 515  /restaurants/panda-momos-dollars-colony-new-be...
#
#                                     RestraNAme
# 0    Leon's - Burgers &amp; Wings (Leon Grill)
# 1                                  Biryani Pot
# 2                                  Burger King
# 3                              Burger Seigneur
# 4                            Sri Punjabi Dhaba
# ..                                         ...
# 511                                 Popcorn Me
# 512                             signature cafe
# 513                              Rich Sandwich
# 514                              Munchous Cafe
# 515                                Panda Momos
#
# [516 rows x 2 columns]

# %%
import re
import pandas as pd

# List to store the restaurant data
restaurant_data = []

# Loop through the html strings and extract the restaurant data
for html in html_list:
#     restaurant_ids = re.findall('data-rest-id="(.*?)"', html)
    restaurant_links = re.findall('<a href="(.*?)">', html)
    name = re.findall('<div class="nA6kb">(.*?)</div>', html)
    rating = re.findall('<span class="icon-star _537e4"></span><span>(.*?)</span>', html)
    cusins = re.findall('<div class="_1gURR" title="(.*?)">', html)
    price = re.findall('<div class="nVWSi">(.*?)</div>', html)
    delivery_time = re.findall('<div>(\d+) MINS</div>', html)
    
    # If price or cusins not found, set it to empty string
    if not price:
        price = [""]
    if not cusins:
        cusins = [""]
        
    # Add the restaurant data to the list
    restaurant_data.append([restaurant_links[0],name[0], rating[0], cusins[0], price[0], delivery_time[0]])
    restaurant_data.append([restaurant_links[1],name[1], rating[1], cusins[1], price[1], delivery_time[1]])
    restaurant_data.append([restaurant_links[2],name[2], rating[2], cusins[2], price[2], delivery_time[2]])


# Create a dataframe from the restaurant data
df88 = pd.DataFrame(restaurant_data, columns=['Link','Restaurant Name', 'Rating', 'Cusins', 'Price for Two', 'Delivery Time'])
df88
# Out:
#                                                   Link  \
# 0    /restaurants/leons-burgers-and-wings-leon-gril...
# 1    /restaurants/biryani-pot-maruti-nagar-btm-layo...
# 2    /restaurants/burger-king-tasker-town-shivaji-n...
# 3    /restaurants/burger-seigneur-st-marks-road-ban...
# 4    /restaurants/sri-punjabi-dhaba-cashier-layout-...
# ..                                                 ...
# 511  /restaurants/popcorn-me-keb-colony-btm-layout-...
# 512  /restaurants/signature-cafe-shivanagar-basaves...
# 513  /restaurants/rich-sandwich-2nd-stage-btm-layou...
# 514  /restaurants/munchous-cafe-1st-stage-btm-layou...
# 515  /restaurants/panda-momos-dollars-colony-new-be...
#
#                                Restaurant Name Rating  \
# 0    Leon's - Burgers &amp; Wings (Leon Grill)    4.2
# 1                                  Biryani Pot    3.9
# 2                                  Burger King    4.2
# 3                              Burger Seigneur    4.4
# 4                            Sri Punjabi Dhaba    3.1
# ..                                         ...    ...
# 511                                 Popcorn Me     --
# 512                             signature cafe     --
# 513                              Rich Sandwich     --
# 514                              Munchous Cafe     --
# 515                                Panda Momos    3.8
#
#                                                 Cusins  Price for Two  \
# 0    American, Snacks, Turkish, Portuguese, Contine...   ₹600 FOR TWO
# 1                                North Indian, Biryani   ₹500 FOR TWO
# 2                                    Burgers, American   ₹350 FOR TWO
# 3                     American, Continental, Beverages  ₹1200 FOR TWO
# 4               North Indian, Biryani, Chinese, Kebabs   ₹300 FOR TWO
# ..                                                 ...            ...
# 511                                             Snacks   ₹200 FOR TWO
# 512                 Pizzas, Burgers, Fast Food, Snacks   ₹150 FOR TWO
# 513                                   Fast Food, Combo   ₹300 FOR TWO
# 514                                   Chinese, Italian   ₹300 FOR TWO
# 515                Asian, Tibetan, Desserts, Beverages   ₹200 FOR TWO
#
#     Delivery Time
# 0              30
# 1              29
# 2              32
# 3              28
# 4              30
# ..            ...
# 511            38
# 512            35
# 513            42
# 514            33
# 515            37
#
# [516 rows x 6 columns]

# %%
df88.to_excel("restaurant_dataExtreame Final4923.xlsx", index=False)

# %%
import re
import pandas as pd

# List to store the restaurant data
restaurant_data = []

# Loop through the html strings and extract the restaurant data
for html in html_list:
#     restaurant_ids = re.findall('data-rest-id="(.*?)"', html)
    restaurant_links = re.findall('<a href="(.*?)">', html)
    name = re.findall('<div class="nA6kb">(.*?)</div>', html)
    rating = re.findall('<span class="icon-star _537e4"></span><span>(.*?)</span>', html)
    cusins = re.findall('<div class="_1gURR" title="(.*?)">', html)
    price = re.findall('<div class="nVWSi">(.*?)</div>', html)
    delivery_time = re.findall('<div>(\d+) MINS</div>', html)
    location = re.findall('<div class="nVWSi">.*?</div><div class=".*?">(.*?)</div>', html)
    
    # If price or cusins not found, set it to empty string
    if not price:
        price = [""]
    if not cusins:
        cusins = [""]
        
    # Add the restaurant data to the list
    restaurant_data.append([restaurant_links[0],name[0], rating[0], cusins[0], price[0], delivery_time[0],location[0]])
    restaurant_data.append([restaurant_links[1],name[1], rating[1], cusins[1], price[1], delivery_time[1],location[1]])
    restaurant_data.append([restaurant_links[2],name[2], rating[2], cusins[2], price[2], delivery_time[2],location[2]])


# Create a dataframe from the restaurant data
df89 = pd.DataFrame(restaurant_data, columns=['Link','Restaurant Name', 'Rating', 'Cusins', 'Price for Two', 'Delivery Time','Address'])
df89
# Out:
#                                                   Link  \
# 0    /restaurants/burger-seigneur-indiranagar-banga...
# 1    /restaurants/raidan-authentic-arabian-restaura...
# 2    /restaurants/the-dessert-zone-2nd-stage-indira...
# 3    /restaurants/kouzina-kafe-the-food-court-cmh-r...
# 4    /restaurants/pipabu-4th-block-koramangala-bang...
# ..                                                 ...
# 427  /restaurants/popcorn-me-keb-colony-btm-layout-...
# 428  /restaurants/signature-cafe-shivanagar-basaves...
# 429  /restaurants/trc-the-roll-company-1st-block-ko...
# 430  /restaurants/rich-sandwich-2nd-stage-btm-layou...
# 431  /restaurants/munchous-cafe-1st-stage-btm-layou...
#
#                           Restaurant Name Rating  \
# 0                         Burger Seigneur    4.3
# 1    Raidan- Authentic Arabian Restaurant    3.9
# 2                        The Dessert Zone    4.2
# 3           Kouzina Kafe - The Food Court    4.2
# 4                                  Pipabu    4.1
# ..                                    ...    ...
# 427                            Popcorn Me     --
# 428                        signature cafe     --
# 429                TRC - The Roll Company     --
# 430                         Rich Sandwich     --
# 431                         Munchous Cafe     --
#
#                                                 Cusins  Price for Two  \
# 0            American, Continental, Burgers, Beverages  ₹1300 FOR TWO
# 1                 Arabian, Chinese, Beverages, Mughlai   ₹400 FOR TWO
# 2               Bakery, Desserts, Ice Cream, Beverages   ₹200 FOR TWO
# 3               Bakery, Desserts, Ice Cream, Beverages   ₹150 FOR TWO
# 4    Pizzas, Italian, American, Continental, Salads...   ₹250 FOR TWO
# ..                                                 ...            ...
# 427                                             Snacks   ₹200 FOR TWO
# 428                 Pizzas, Burgers, Fast Food, Snacks   ₹150 FOR TWO
# 429                                             Snacks   ₹300 FOR TWO
# 430                                   Fast Food, Combo   ₹300 FOR TWO
# 431                                   Chinese, Italian   ₹300 FOR TWO
#
#     Delivery Time                                            Address
# 0              28  <span role="button" aria-label="Open" class="_...
# 1              30  <span class="icon-offer-filled _2fujs"></span>...
# 2              23  <span class="icon-offer-filled _2fujs"></span>...
# 3              33  <span class="icon-offer-filled _2fujs"></span>...
# 4              30  <span class="icon-offer-filled _2fujs"></span>...
# ..            ...                                                ...
# 427            38  <span role="button" aria-label="Open" class="_...
# 428            34  <span role="button" aria-label="Open" class="_...
# 429            35  <span role="button" aria-label="Open" class="_...
# 430            41  <span role="button" aria-label="Open" class="_...
# 431            33  <span class="icon-offer-filled _2fujs"></span>...
#
# [432 rows x 7 columns]
